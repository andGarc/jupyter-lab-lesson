# %%
import pandas as pd

# %%
data = ['l', 'l', 'a', 'm', 'a']
s = pd.Series(data)

# %%
s.describe()
# Out:
# count     5
# unique    3
# top       a
# freq      2
# dtype: object

# %%
print(s)
# Out:
# 0    l
# 1    l
# 2    a
# 3    m
# 4    a
# dtype: object
